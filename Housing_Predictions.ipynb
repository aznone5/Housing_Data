# %% [markdown]
# ## House Prices - Advanced Regression Techniques
# * By Jackie Nguyen
# * github:https://github.com/aznone5
# * linkedin:https://www.linkedin.com/in/jackie-dan-nguyen/
# * Kaggle Competition: https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/code

# %% [markdown]
# ## Objective
# * Edit null values and remove outliers from train/test sets
# * Label encode certain columns to transform into integer typing
# * Use RandomForestRegressor Model and RandomSearchCv to find the appropriate hyperparameters, and fitting, to best predict column "SalePrice"
# * Apply and predict on the test dataset.
# * Summit to kaggle in a submission format of 2 columns, id and SalePrice.

# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train.Exterior2nd.unique()
# Out:
# array(['VinylSd', 'MetalSd', 'Wd Shng', 'HdBoard', 'Plywood', 'Wd Sdng',
#        'CmentBd', 'BrkFace', 'Stucco', 'AsbShng', 'Brk Cmn', 'ImStucc',
#        'AsphShn', 'Stone', 'Other', 'CBlock'], dtype=object)

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ## Feature Engineering

# %%
def remove_null_columns(df, threshold=0.3):
    null_percentages = df.isnull().mean()
    columns_to_drop = null_percentages[null_percentages > threshold].index
    df.drop(columns=columns_to_drop, inplace=True)
    return df

# %%
def fill_null(df):
    for column in df.columns:
        if df[column].dtype in [int, float]:
            df[column].fillna(0, inplace=True)
        elif df[column].dtype == object:
            df[column].fillna('', inplace=True)
    
    return df

# %%
remove_null_columns(train)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
remove_null_columns(test)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
fill_null(train)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
fill_null(test)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
def remove_outliers(df, threshold=1.5):
    num_cols = df.select_dtypes(include=np.number).columns
    
    for col in num_cols:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        upper_limit = q3 + threshold * iqr
        lower_limit = q1 - threshold * iqr
        
        df[col] = np.where(df[col] > upper_limit, upper_limit, np.where(df[col] < lower_limit, lower_limit, df[col]))
    
    return df

# %%
remove_outliers(train)
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave      Reg
# 1        2.0        20.0       RL         80.0   9600.0   Pave      Reg
# 2        3.0        60.0       RL         68.0  11250.0   Pave      IR1
# 3        4.0        70.0       RL         60.0   9550.0   Pave      IR1
# 4        5.0        60.0       RL         84.0  14260.0   Pave      IR1
# ...      ...         ...      ...          ...      ...    ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
remove_outliers(test)
# Out:
#           Id  MSSubClass MSZoning  LotFrontage   LotArea Street LotShape  \
# 0     1461.0        20.0       RH         80.0  11622.00   Pave      Reg
# 1     1462.0        20.0       RL         81.0  14267.00   Pave      IR1
# 2     1463.0        60.0       RL         74.0  13830.00   Pave      IR1
# 3     1464.0        60.0       RL         78.0   9978.00   Pave      IR1
# 4     1465.0       120.0       RL         43.0   5005.00   Pave      IR1
# ...      ...         ...      ...          ...       ...    ...      ...
# 1454  2915.0       145.0       RM         21.0   1936.00   Pave      Reg
# 1455  2916.0       145.0       RM         21.0   1894.00   Pave      Reg
# 1456  2917.0        20.0       RL        129.0  17707.25   Pave      Reg
# 1457  2918.0        85.0       RL         62.0  10441.00   Pave      Reg
# 1458  2919.0        60.0       RL         74.0   9627.00   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %% [markdown]
# ## Label Encode

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def encode(df):
    label_encoder = LabelEncoder()
    
    for column in df.columns:
        if df[column].dtype == object:
            df[column] = label_encoder.fit_transform(df[column].astype(str))
    
    return df

# %%
encode(train)
# Out:
#           Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0        1.0        60.0         3         65.0   8450.0       1         3
# 1        2.0        20.0         3         80.0   9600.0       1         3
# 2        3.0        60.0         3         68.0  11250.0       1         0
# 3        4.0        70.0         3         60.0   9550.0       1         0
# 4        5.0        60.0         3         84.0  14260.0       1         0
# ...      ...         ...       ...          ...      ...     ...       ...
# 1455  1456.0        60.0         3         62.0   7917.0       1         3
# 1456  1457.0        20.0         3         85.0  13175.0       1         3
# 1457  1458.0        70.0         3         66.0   9042.0       1         3
# 1458  1459.0        20.0         3         68.0   9717.0       1         3
# 1459  1460.0        20.0         3         75.0   9937.0       1         3
#
# ...

# %%
encode(test)
# Out:
#           Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 0     1461.0        20.0         3         80.0  11622.00       1         3
# 1     1462.0        20.0         4         81.0  14267.00       1         0
# 2     1463.0        60.0         4         74.0  13830.00       1         0
# 3     1464.0        60.0         4         78.0   9978.00       1         0
# 4     1465.0       120.0         4         43.0   5005.00       1         0
# ...      ...         ...       ...          ...       ...     ...       ...
# 1454  2915.0       145.0         5         21.0   1936.00       1         3
# 1455  2916.0       145.0         5         21.0   1894.00       1         3
# 1456  2917.0        20.0         4        129.0  17707.25       1         3
# 1457  2918.0        85.0         4         62.0  10441.00       1         3
# 1458  2919.0        60.0         4         74.0   9627.00       1         3
#
# ...

# %% [markdown]
# ## Model

# %%
train['Id'] = train['Id'].astype(int)
test['Id'] = test['Id'].astype(int)

X = train.drop(['SalePrice'], axis = 1)
y = train['SalePrice']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# %%
from sklearn.ensemble import RandomForestRegressor


model = RandomForestRegressor()

random = RandomizedSearchCV(model, param_grid, n_iter=15, scoring='neg_mean_squared_error', random_state=42)

best_model = random.fit(X_train, y_train)
y_pred = best_model.predict(X_test)

best_model = random.best_estimator_
best_params = random.best_params_

# %%
y_pred = best_model.predict(test)

sub = pd.DataFrame({"Id": test['Id'], "SalePrice": y_pred})
sub.head()
# Out:
#      Id      SalePrice
# 0  1461  124854.889167
# 1  1462  146797.623449
# 2  1463  184877.817175
# 3  1464  178322.439062
# 4  1465  212522.699243

# %%
sub.to_csv('submission.csv', index=False)
